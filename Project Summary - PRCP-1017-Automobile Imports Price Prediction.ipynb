# %% [markdown]
# ## Project Summary
#
# Determining the price of a car is a challenging task, due to the many factors that drive a vehicle’s price on the market. The focus of this project is to develope machine learning models that can accurately predict the price of a car based on its features. Mainly, there are two project objectives:
#
# - To find the variables which are significant in predicting the car price
# - To find most relevant machine learning model which predicts best car price for given dataset
#
# The input file is given as an excel csv file which contains 201 records of different cars information and 26 total features which are very well defined. The shape of the data is (201 X 26). These 26 features are classified as 16 numerical and 10 categorical data. The dataset has total 51 missing values which are denoted as "?". Based on the Normality tests of numerical variables with missing values, it has been decided to replace all numerical missing values with Median values of that perticular column. Categorical missing values are replaced with Mode value of that column.
#
# The Machine Learning Regressor Models are used to find the R2-score & Mean_absolute_error of the data. Two types of datasets have been used : One dataset consists of All Outliers of Predictor and Target Variables where as in second dataset Outliers of Target variables are dropped. The models used are:
#
# 1. Linear Regression
# 2. XG Boost Regression
# 3. Random Forest Regression
#
# From these models XG Boost Regressor algorithm gives the better R2-Score of 95% and lesser Mean_absolute_error of 992.

# %% [markdown]
# ###  Analysis
#
# The analysis is done by analyzing the various features of the data. It has 26 features which plays important role in analysis of data with many prespectives. Many packages such as numpy, pandas,etc., are used to analyze the fearures. The features are categorized into Numerical and Categorical datas.
#
# #### Missing Values
#
# In excel file, it contains 201X26 data. The following attributes have missing values:-
#
# ##### Attributes                                      :        Number of missing values
# 1. Normalized_losses : 37
# 2. Num of Doors      : 2
# 3. Bore              : 4
# 4. Stroke            : 4
# 5. Horsepower        : 2
# 6. Peak RPM          : 2
#
# For filing the missing values in the following attributes, 1) Convert'?' with nan 2) convert the following attributes into float 3) Fill the missing value with median (because median represents the middle value of data either in ascending or descending order).
#
# #### Categorical Features
# Categorical features are those which classify values into sets of similar samples and the values are nominal, ordinal, ratio, or interval based. The categorical features as follows:
#
# * Make
# * Fuel_type
# * Aspiration
# * Num of Doors
# * Body style
# * Drive Wheels
# * Engine Location
# * Engine Type
# * Num of Cylinders
# * Fuel_system
#
# #### Numerical Features
# Numerical features are the values which varies in a particular range and classified as discrete, continuous, or timeseries based. The Numerical Features as follows:
# * Symboling
# * Normalized losses
# * Wheel base
# * Length
# * Width
# * Height
# * Curb weight
# * Engine size
# * Bore
# * Stroke
# * Compression ratio
# * Horsepower
# *  Peak RPM
# * City mpg
# * Highway mpg
# * Price

# %% [markdown]
# ### Machine Learning Model
# The machine learning models used in this project are
#
# - 1.Linear Regression
#
#     Linear Regression was chosen as the first model due to its simplicity and comparatively small training time.
#
#
# - 2.RandomForestRegressor
#
#     Random Forest is an ensemble learning based regression model. It uses a model called decision tree, specifically as the name suggests, multiple decision trees to generate the ensemble model which collectively produces a prediction. The benefit of this model is that the trees are produced in parallel and are relatively uncorrelated, thus producing good results as each tree is not prone to individual errors of other trees.
#
#
# - 3.XGBoost Regressor
#
#     Extreme Gradient Boosting or XGBoost is one of the most popular machine learning models in current times. XGBoost is quite similar at the core to the original gradient boosting algorithm but features many additive features that significantly improve its performance such as built in support for regularization, parallel processing as well as giving additional hyperparameters to tune such as tree pruning, sub sampling and number of decision trees. A maximum depth of 5 was used and the algorithm was run on all cores in parallel
#
# All these machine learning algorithms are best for regression problem. The train and test data are divided into 80:20 ratio and fitted into the model and passed through the machine learning. The dataset here used is including All outliers of Predictor and Target variables.
#
# The predicted data and test data achieved the accuracy rate of,
#
# * 1.Linear Regression - 80% with Mean_absolute_error of 2250
# * 2.RandomForestRegressor - 88.5% with Mean_absolute_error 1658
# * 3.XGBoost Regressor - 95.1% with Mean_absolute_error 992

# %% [markdown]
# ## 3. Summary
#
# The 3 machine learning model has been fitted and predicted with the r2 score.
# The objective of this project is to predict the results from the analysis and machine learning model.
#
# ### Objective 1: To find the variables which are significant in predicting the car price
#
# EDA or Exploratory Data Analysis was performed on categorical variables using various graphs to explore the impoact on the target variable. After careful analysis, features such as fuel_type, body_style, engine_location, engine_type, num_of_cylinders, fuel_system, make, aspiration were selected.
#
# Correlation matrix was used to find the impact of numarical variables on the target variable price. Positively correlated variables were cosidered if the correlation value is greater than  0.5 while negetive correlated variables were considered if the correlation value is below -0.5.
# The selected variables after correlation matrix is as below:
# - wheel_base
# - length
# - width
# - curb_weight
# - engine_size
# - bore
# - horsepower
# - city_mpg
# - highway_mpg
#
# ### Objective 2: To find most relevant machine learning model which predicts best car price for given dataset
#
# The results of our tests are quantified in terms of R2-score and Mean_absolute_error of our predictions. R2-score is a statistical measure of how close the data are to the fitted regression line. The mean absolute error is the sum of absolute errors over the length of observations / predictions. Compared to Linear Regression, other methods did perform comparably well. XG Boost Regression method marginally outperforms Random Forest Regression Method. Both the XG Boost Regressor and Random Forest Regressor models have been trained and observed with different values of depth of trees and limited to 6 for the best results.
#
# * 1.Linear Regression - 80% with Mean_absolute_error of 2250
# * 2.RandomForestRegressor - 88.5% with Mean_absolute_error 1658
# * 3.XGBoost Regressor - 95.1% with Mean_absolute_error 992
#
# ##### XGBoostRegressor gives the best prediction for car price.
